# %% [markdown]
# # Building A Personal Safety Equipment Detection System

# %% [markdown]
# ### Loading all the imports

# %%
import cv2
import numpy as np
import pandas as pd
import os
import glob
import tensorflow as tf
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Dataset Details:- Hardhat/head detection dataset, annotation format: Pascal VOC (XMLs)**
# - **Dataset Size:- `Data with Annotations: 4750` and `Data without Annotations (Test): 250`**
# - **Dataset classes of interest: `helmet` & `head`**

# %% [markdown]
# ### Transforming Pascal VOC Annotations into YOLO Format

# %%
image_dir = "C:\\Users\\kbtha\\Desktop\\PSE Detection System\\Dataset\\HardHat_Dataset\\images"
annotation_dir = "C:\\Users\\kbtha\\Desktop\\PSE Detection System\\Dataset\\HardHat_Dataset\\annotations"
yolo_dir = "C:\\Users\\kbtha\\Desktop\\PSE Detection System\\Dataset\\HardHat_Dataset\\labels"
os.makedirs(yolo_dir, exist_ok=True)

classes = {"helmet":0, "head":1}

for xml_file in glob.glob(os.path.join(annotation_dir, "*.xml")):
    image_file = os.path.join(image_dir, os.path.basename(xml_file).replace(".xml",".png"))
    if os.path.exists(image_file):
        img_read = cv2.imread(image_file)
        img_width, img_height, channels = img_read.shape
        
        # parse the xml file
        tree = ET.parse(xml_file)
        root = tree.getroot()
    
        # get the txt_filename (without extension)
        txt_filename = os.path.splitext(os.path.basename(xml_file))[0] + ".txt"
        
        # open a new yolo label file
        with open(os.path.join(yolo_dir,txt_filename), "w") as f:
            for obj in root.findall("object"):
                class_name = obj.find("name").text
                # skip classes not in mapping
                if class_name not in classes:
                    continue
                class_id = classes[class_name]
                bbox = obj.find("bndbox")
                xmin = int(bbox.find("xmin").text)
                ymin = int(bbox.find("ymin").text)
                xmax = int(bbox.find("xmax").text)
                ymax = int(bbox.find("ymax").text)
                # converting coordinates to YOLO format
                x_center = (xmin + xmax) / 2.0 / img_width
                y_center = (ymin + ymax) / 2.0 / img_height
                width = (xmax - xmin) / img_width
                height = (ymax - ymin) / img_height
                
                # Write the converted annotation to file
                f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")
            
print("Conversion completed! YOLO labels saved in:", yolo_dir)
# Out:
# Conversion completed! YOLO labels saved in: C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\labels

# %% [markdown]
# ### Visualizing YOLO Dataset

# %%
image_dir = "C:\\Users\\kbtha\\Desktop\\PSE Detection System\\Dataset\\HardHat_Dataset\\images"
annotation_dir = "C:\\Users\\kbtha\\Desktop\\PSE Detection System\\Dataset\\HardHat_Dataset\\annotations"
visualize_dir = "C:\\Users\\kbtha\\Desktop\\PSE Detection System\\Dataset\\HardHat_Dataset\\vis"
os.makedirs(visualize_dir, exist_ok=True)

class_names = ["helmet", "head"]
object_colors = [(0,0,255), (0,255,0)]
hist = [0, 0]

def yolo2bbox(bboxes):
    xmin, ymin = bboxes[0]-bboxes[2]/2, bboxes[1]-bboxes[3]/2
    xmax, ymax = bboxes[0]+bboxes[2]/2, bboxes[1]+bboxes[3]/2
    return xmin, ymin, xmax, ymax

def plot_box(image, bboxes, labels):
    # Need the image height and width to denormalize the bounding box coordinates
    out_img = image.copy()
    img_width, img_height, channels = image.shape
    for box_num, box in enumerate(bboxes):
        x1, y1, x2, y2 = yolo2bbox(box)
        # denormalize the coordinates
        xmin = int(x1*img_width)
        ymin = int(y1*img_height)
        xmax = int(x2*img_width)
        ymax = int(y2*img_height)
        width = xmax - xmin
        height = ymax - ymin
        c = int(labels[box_num])
        cv2.rectangle(out_img, (xmin, ymin), (xmax, ymax), color=object_colors[c], thickness=2)
        hist[c] = hist[c] + 1
        '''
        cv2.putText(image, class_names[int(labels[box_num])], (xmin+1, ymin-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        '''
    return out_img
# '*.[pj][np]g' it allows finding both .jpg, .jpeg, and .png files in one pattern.
for image_file in glob.glob(os.path.join(image_dir,'*.[pj][np]g')):
    label_file = image_file.replace("images","labels").replace(".jpg",".txt") # we can remove this
    label_file = label_file.replace(".png",".txt")
    
    print(image_file)
    image = cv2.imread(image_file)

    with open(label_file, 'r') as f:
        bboxes = []
        labels = []
        label_lines = f.readlines()
        for label_line in label_lines:
            label = label_line[0]
            bbox_string = label_line[2:]
            x_c, y_c, w, h = bbox_string.split(' ')
            x_c = float(x_c)
            y_c = float(y_c)
            w = float(w)
            h = float(h)
            bboxes.append([x_c, y_c, w, h])
            labels.append(label)
    result_image = plot_box(image, bboxes, labels)

    out_file = os.path.join(visualize_dir,os.path.basename(image_file).replace('.jpg', '.png'))
    #cv2.imwrite(out_file, cv2.hconcat([image, result_image]))
    cv2.imwrite(out_file, result_image)
    print(hist)
# Out:
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers0.png
# [7, 6]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1.png
# [16, 6]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers10.png
# [19, 6]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers100.png
# [24, 6]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1000.png
# [26, 6]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1001.png
# [30, 6]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1002.png
# [34, 6]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1003.png
# [40, 6]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1004.png
# [45, 6]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1005.png
# [50, 8]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1006.png
# [52, 24]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1007.png
# [55, 25]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1008.png
# [58, 25]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1009.png
# [62, 25]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers101.png
# [62, 30]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1010.png
# [62, 36]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1011.png
# [64, 36]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1012.png
# [69, 36]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1013.png
# [73, 42]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1014.png
# [73, 50]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1016.png
# [83, 50]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1017.png
# [85, 51]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1019.png
# [92, 51]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers102.png
# [95, 51]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1020.png
# [103, 51]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1021.png
# [111, 51]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1022.png
# [115, 51]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1023.png
# [122, 51]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1024.png
# [122, 59]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1025.png
# [124, 59]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1026.png
# [137, 59]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1027.png
# [141, 59]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1028.png
# [143, 59]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1029.png
# [145, 59]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers103.png
# [147, 59]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1030.png
# [159, 59]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1032.png
# [170, 59]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1033.png
# [176, 59]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1034.png
# [176, 71]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1035.png
# [176, 82]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1036.png
# [179, 82]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1037.png
# [181, 82]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1038.png
# [181, 98]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1039.png
# [184, 98]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers104.png
# [184, 103]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1040.png
# [187, 103]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1041.png
# [189, 103]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1042.png
# [190, 104]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1043.png
# [194, 104]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1045.png
# [201, 104]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1046.png
# [202, 104]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1047.png
# [202, 109]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1048.png
# [203, 109]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1049.png
# [207, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers105.png
# [214, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1050.png
# [216, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1051.png
# [220, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1052.png
# [224, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1053.png
# [228, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1054.png
# [230, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1055.png
# [231, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1056.png
# [234, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1057.png
# [238, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1058.png
# [244, 115]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1059.png
# [244, 120]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers106.png
# [246, 120]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1060.png
# [255, 120]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1061.png
# [258, 120]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1062.png
# [259, 120]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1063.png
# [263, 120]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1064.png
# [267, 120]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1065.png
# [268, 120]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1066.png
# [268, 126]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1067.png
# [276, 127]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1069.png
# [282, 127]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers107.png
# [284, 127]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1070.png
# [291, 127]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1071.png
# [298, 127]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1073.png
# [307, 127]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1074.png
# [312, 127]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1075.png
# [315, 127]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1076.png
# [318, 127]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1077.png
# [322, 128]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1078.png
# [329, 128]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1079.png
# [343, 130]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers108.png
# [345, 130]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1080.png
# [350, 140]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1081.png
# [357, 143]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1082.png
# [367, 145]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1083.png
# [368, 145]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1084.png
# [371, 145]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1085.png
# [373, 145]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1086.png
# [375, 145]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1087.png
# [376, 145]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1088.png
# [378, 145]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1089.png
# [378, 147]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers109.png
# [382, 147]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers1090.png
# [386, 147]
# C:\Users\kbtha\Desktop\PSE Detection System\Dataset\HardHat_Dataset\images\hard_hat_workers
"C:\\Users\\kbtha\\Desktop\\PSE Detection System\\Dataset\\HardHat_Dataset\\images"
label_folder = "C:\\Users\\kbtha\\Desktop\\PSE Detection System\\Dataset\\HardHat_Dataset\\labels"

# Create YOLO directories
for folder in ["train/images", "train/labels", "val/images", "val/labels"]:
    os.makedirs(os.path.join(dataset_path, folder), exist_ok=True)

# Get all image files (supports .jpg, .png)
image_files = [f for f in os.listdir(image_folder) if f.endswith((".jpg", ".png"))]

# Shuffle and split into train/val (80% train, 20% val)
random.shuffle(image_files)
split_index = int(0.95 * len(image_files))
train_images = image_files[:split_index]
val_images = image_files[split_index:]

# Function to move files to respective folders
def move_files(file_list, split_type):
    for file in file_list:
        image_src = os.path.join(image_folder, file)
        label_src = os.path.join(label_folder, file.replace(".jpg", ".txt").replace(".png", ".txt"))
        
        # Destination paths
        image_dst = os.path.join(dataset_path, f"{split_type}/images", file)
        label_dst = os.path.join(dataset_path, f"{split_type}/labels", file.replace(".jpg", ".txt").replace(".png", ".txt"))
        
        # Move image
        shutil.copy(image_src, image_dst)
        
        # Move corresponding label if exists
        if os.path.exists(label_src):
            shutil.copy(label_src, label_dst)

# Move training and validation files
move_files(train_images, "train")
move_files(val_images, "val")

print("Dataset structured in YOLO format successfully!")
# Out:
# Dataset structured in YOLO format successfully!

# %% [markdown]
# ### Generate data.yaml Automatically

# %%
# Define class names
class_names = ["helmet", "head"]

# Create `data.yaml`
yaml_content = rf"""train: {dataset_path}\train\images\
val: {dataset_path}\val\images\

nc: {len(class_names)}
names: {class_names}
"""

# Save `data.yaml`
with open(os.path.join(dataset_path, "data.yaml"), "w") as f:
    f.write(yaml_content)

print("data.yaml file created successfully!")
# Out:
# data.yaml file created successfully!

# %% [markdown]
# ### YOLO Dataset Statistics: Count Images and Labels

# %%
import glob
train_img_path = r"C:\Users\kbtha\Desktop\PSE Detection System\data\train\images"
val_img_path = r"C:\Users\kbtha\Desktop\PSE Detection System\data\val\images"

def get_stats(train=True):
    if train:
        mask = os.path.join(train_img_path,'*.[pj][np]g')
    else:
        mask = os.path.join(val_img_path,'*.[pj][np]g')
        
    class_names = ["helmet", "head"]
    hist = [0,0]
    num_images = 0
    for image_file in glob.glob(mask):
        label_file = image_file.replace("images","labels").replace(".jpg",".txt")
        label_file = label_file.replace(".png",".txt")
        num_images = num_images + 1
        
        with open(label_file, 'r') as f:
            bboxes = []
            labels = []
            label_lines = f.readlines()
            for label_line in label_lines:
                label = int(label_line[0])
                hist[label] = hist[label]+1
                
    print("Number of images: ", num_images)
    for c in enumerate(class_names):
        print(c[1], ":", hist[c[0]])

print("Training Set Stats\n")
get_stats(True)
print("Validation Set Stats\n")
get_stats(False)
# Out:
# Training Set Stats
#
# Number of images:  4512
# helmet : 17117
# head : 5217
# Validation Set Stats
#
# Number of images:  238
# helmet : 923
# head : 274
